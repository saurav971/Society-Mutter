# %%
from transformers import pipeline

# %%
import pandas as pd

# %%
df = pd.DataFrame([('EN',text)]*10, columns=['Lang','Text'])

# %%
text = """
A computer is a digital electronic machine that can be programmed to carry out sequences of arithmetic or logical operations (computation) automatically
"""

# %%
smr_bart = pipeline(task="summarization", model="facebook/bart-large-cnn")
# Out:
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=1585.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=1625692088.0), HTML(value='')))
# All model checkpoint layers were used when initializing TFBartForConditionalGeneration.
#
# All the layers of TFBartForConditionalGeneration were initialized from the model checkpoint at facebook/bart-large-cnn.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBartForConditionalGeneration for predictions without further training.
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=898823.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=456318.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=1355863.0), HTML(value='')))

# %%
smbart = smr_bart(text, max_length=150)
# Out:
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)

# %%
print(smbart[0]['summary_text'])
# Out:
# A computer is a digital electronic machine that can be programmed to carry out sequences of arithmetic or logical operations (computation) automatically. A computer is an electronic machine with a built-in operating system. It can be used to perform arithmetic and logical operations automatically.

# %%
df['summary'] = df.apply(lambda x: smr_bart(x['Text'], max_length=150)[0]['summary_text'] , axis=1)
# Out:
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)

# %%
df.head(3)
# Out:
#   Lang                                               Text  \
# 0   EN  \nA computer is a digital electronic machine t...
# 1   EN  \nA computer is a digital electronic machine t...
# 2   EN  \nA computer is a digital electronic machine t...
#
#                                              summary
# 0  A computer is a digital electronic machine tha...
# 1  A computer is a digital electronic machine tha...
# 2  A computer is a digital electronic machine tha...

# %%
df.iloc[1]['summary']
# Out:
# 'A computer is a digital electronic machine that can be programmed to carry out sequences of arithmetic or logical operations (computation) automatically. A computer is an electronic machine with a built-in operating system. It can be used to perform arithmetic and logical operations automatically.'

# %%
# Out:
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
# Your max_length is set to 150, but you input_length is only 31. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=15)
